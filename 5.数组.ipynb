# %% [markdown]
# JavaScript 数组在 TypeScript 里面分成两种类型，分别是数组（array）和元组（tuple）。
# # 简介
# TypeScript 数组有一个根本特征：所有成员的类型必须相同，但是成员数量是不确定的，可以是无限数量的成员，也可以是零成员。

# %%
let arr: number[] = [1, 2, 3]

# %% [markdown]
# 如果数组成员的类型比较复杂，可以写在圆括号里面。

# %%
let arr3: (number | string)[] = [1, "333", true]   // 无法重新声明块范围变量“arr3”。ts(2451)

# %% [markdown]
# # 数组的类型推断

# %%
// 推断为 any[]
const arr = [];

arr // 推断为 any[]

arr.push(123);
arr // 推断类型为 number[]

arr.push('abc');
arr // 推断类型为 (string|number)[]
console.log(arr)

# %% [markdown]
# # 只读数组 const断言

# %%
const arr:readonly number[] = [0, 1];
arr[1]; // 报错
arr.push(3); // 报错
delete arr[0]; // 报错

# %% [markdown]
# # 多维数组

# %%
var multi:number[][] =
  [[1,2,3], [23,24,25]];
