# %% [markdown]
# # 基本用法
# ## 类型声明
# TypeScript 代码最明显的特征，就是为 JavaScript 变量加上了类型声明。

# %%
// 变量foo的后面使用冒号，声明了它的类型为string。
let foo: string;

// 函数toString()的参数num的类型是number。参数列表的圆括号后面，声明了返回值的类型是string。
function toString(num: number): string {
    return new String(num)
}

// 报错
let foo:string = 123;
# Out:
# 2:5 - Cannot redeclare block-scoped variable 'foo'.
# 6:16 - Cannot find name 'String'.
# 10:5 - Type 'number' is not assignable to type 'string'.
# 10:5 - Cannot redeclare block-scoped variable 'foo'.

# %% [markdown]
# **TypeScript 规定，变量只有赋值后才能使用，否则就会报错。**

# %%
let x:number = 1;
console.log(x) // 报错
# Out:
# 1:5 - Type 'number' is not assignable to type 'string'.

# %% [markdown]
# ## 类型推断
# 类型声明并不是必需的，如果没有，TypeScript 会自己推断类型。

# %%
// 变量foo并没有类型声明，TypeScript 就会推断它的类型。由于它被赋值为一个数值，因此 TypeScript 推断它的类型为number
let foo = 123;

let foo = 123;
foo = 'hello'; // 报错
# Out:
# 123222

# %% [markdown]
# ## tsc 编译器
# TypeScript 官方提供的编译器叫做 tsc，可以将 TypeScript 脚本编译成 JavaScript 脚本。本机想要编译 TypeScript 代码，必须安装 tsc。
# #### 安装
# npm install -g typescript
# 检查版本： tsc -v
# ## ts-node
# 可以直接运行 TypeScript 代码
